# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
loans = pd.read_csv("loan_data.csv")

# %%
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc
# 0              1  debt_consolidation    0.1189       829.10       11.350407  \
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths
# 0  19.48   737        5639.958333      28854        52.1               0  \
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loans.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000  \
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util
# count  9578.000000        9578.000000  9.578000e+03  9578.000000  \
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
sns.histplot(data = loans, x = 'fico', hue = 'credit.policy')
# Out:
# <Axes: xlabel='fico', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
loans[loans['credit.policy']==1]['fico'].hist(alpha=0.5,color='blue',
                                              bins=30,label='Credit.Policy=1')
loans[loans['credit.policy']==0]['fico'].hist(alpha=0.5,color='red',
                                              bins=30,label='Credit.Policy=0')
plt.legend()
plt.xlabel('FICO')
# Out:
# Text(0.5, 0, 'FICO')

# %%
sns.histplot(data = loans, x = 'fico', hue = 'not.fully.paid')
# Out:
# <Axes: xlabel='fico', ylabel='Count'>

# %%
plt.figure(figsize = (12, 6))

loans[loans['not.fully.paid'] == 0]['fico'].hist(alpha = .5, color = 'red', label = 'Not fully paid', bins = 30)
loans[loans['not.fully.paid'] == 1]['fico'].hist(alpha = .5, color = 'Blue', label = 'Fully paid', bins =30)
plt.legend()
plt.xlabel('FICO')
# Out:
# Text(0.5, 0, 'FICO')

# %%
sns.countplot(data = loans, x = 'purpose', hue = 'not.fully.paid')
plt.tight_layout()

# %%
sns.jointplot(data = loans, x = 'fico', y = 'int.rate')

# %%
sns.lmplot(data = loans, x = 'fico', y = 'int.rate', hue = 'credit.policy', col = 'not.fully.paid')

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
cat_feats = ['purpose']

final_data = pd.get_dummies(data = loans, columns = cat_feats, drop_first = True )

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   credit.policy               9578 non-null   int64
#  1   int.rate                    9578 non-null   float64
#  2   installment                 9578 non-null   float64
#  3   log.annual.inc              9578 non-null   float64
#  4   dti                         9578 non-null   float64
#  5   fico                        9578 non-null   int64
#  6   days.with.cr.line           9578 non-null   float64
#  7   revol.bal                   9578 non-null   int64
#  8   revol.util                  9578 non-null   float64
#  9   inq.last.6mths              9578 non-null   int64
#  10  delinq.2yrs                 9578 non-null   int64
#  11  pub.rec                     9578 non-null   int64
#  12  not.fully.paid              9578 non-null   int64
# ...

# %%
final_data.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico
# 0              1    0.1189       829.10       11.350407  19.48   737  \
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs
# 0        5639.958333      28854        52.1               0            0  \
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid  purpose_credit_card  purpose_debt_consolidation
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
final_data.columns
# Out:
# Index(['credit.policy', 'int.rate', 'installment', 'log.annual.inc', 'dti',
#        'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid',
#        'purpose_credit_card', 'purpose_debt_consolidation',
#        'purpose_educational', 'purpose_home_improvement',
#        'purpose_major_purchase', 'purpose_small_business'],
#       dtype='object')

# %%
X = final_data.drop('not.fully.paid', axis = 1)
y = final_data['not.fully.paid']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.3, random_state = 101)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictdtree = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_true = y_test, y_pred = predictdtree))
print()
print(classification_report(y_true = y_test, y_pred = predictdtree))
# Out:
# [[4671  980]
#  [ 790  264]]
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84      5651
#            1       0.21      0.25      0.23      1054
#
#     accuracy                           0.74      6705
#    macro avg       0.53      0.54      0.54      6705
# weighted avg       0.75      0.74      0.74      6705

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predictrfc = rfc.predict(X_test)

# %%
print(confusion_matrix(y_true = y_test, y_pred = predictrfc))
print()
print(classification_report(y_true = y_test, y_pred = predictrfc))
# Out:
# [[5595   56]
#  [1023   31]]
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91      5651
#            1       0.36      0.03      0.05      1054
#
#     accuracy                           0.84      6705
#    macro avg       0.60      0.51      0.48      6705
# weighted avg       0.77      0.84      0.78      6705
